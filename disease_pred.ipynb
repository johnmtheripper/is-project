# %% [markdown]
# <a href="https://colab.research.google.com/github/munenedev/is_project_2/blob/main/disease_pred.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mount Google Drive

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Importing the dataset

# %%
# importing libraries
import tensorflow
import keras
import os
import glob
from skimage import io
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# importing and loading data into a DataFrame
dataset_path = "/content/gdrive/MyDrive/Dataset/train"
class_names = ['bacterial_blight', 'curl_virus','fusarium_wilt', 'healthy']

# apply glob module to retrieve files/pathnames  
diseases_path = os.path.join(dataset_path, class_names[1], '*')
diseases_path = glob.glob(diseases_path)

# %%
# accessing an image file from the dataset classes
image = io.imread(diseases_path[4])  

# plotting the original image
i, (im1) = plt.subplots(1)
i.set_figwidth(15)
im1.imshow(image)

# %% [markdown]
# Data Preprocessing

# %%
# plotting the original image and the RGB channels  

i, (im1, im2, im3, im4) = plt.subplots(1, 4, sharey=True)
i.set_figwidth(20) 

im1.imshow(image)  #Original image
im2.imshow(image[:, : , 0]) #Red
im3.imshow(image[:, : , 1]) #Green
im4.imshow(image[:, : , 2]) #Blue
i.suptitle('Original & RGB image channels')
# Out:
# Text(0.5, 0.98, 'Original & RGB image channels')
